# %% [markdown]
# <a href="https://colab.research.google.com/github/the-vyld/clothing-similarity/blob/main/ClothingSimilarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
name = []
price = []
url = []
brand = []

for i in range (0, 1440, 72): 
  cookies = {
      'geocountry': 'IN',
      '_abck': '0964C38D588870D3AB8A8A2AD61310FE~0~...~-1~-1~1684446798',
      'bm_sz': '830FB7A87E1079BFB86914F1B1D2DB4D~~3356998~3619137',
      'AMCV_C0137F6A52DEAFCC0A490D4C%40AdobeOrg': '-1303530583%7CMCMID%7C60069574564088357800626577175423412725%7CvVersion%7C3.3.0%7CMCAID%7CNONE%7CMCOPTOUT-1684450400s%7CNONE',
      's_pers': '%20s_vnum%3D1685557800077%2526vn%253D2%7C1685557800077%3B%20gpv_e231%3Daaea1c58-553f-4186-a485-470a8fbf5138%7C1684445106753%3B%20eVar225%3D6%7C1684445106798%3B%20s_invisit%3Dtrue%7C1684445106804%3B%20visitCount%3D2%7C1684445106810%3B',
      'siteChromeVersion': 'au=12&com=12&de=12&dk=12&es=12&fr=12&it=12&nl=12&pl=12&roe=12&row=12&ru=12&se=12&us=12',
      'keyStoreDataversion': 'ornjx7v-36',
      'browseCountry': 'IN',
      'asos': 'PreferredSite=&customerguid=faf8d120b9f74c3bbbb75e88c6b2f10f&topcatid=1001',
      'browseCurrency': 'GBP',
      'browseLanguage': 'en-GB',
      'browseSizeSchema': 'UK',
      'storeCode': 'ROW',
      'currency': '1',
      'stc-welcome-message': 'cappedPageCount=2',
      'featuresId': '2f6f608c-9479-4050-abf6-816c593452db',
      'asos-b-sdv629': 'ornjx7v-36',
      'ak_bmsc': '960553D8D25C8448720724CF9E5B0EF5~000000000000000000000000000000~...',
      'bm_sv': '8733192C061BDF489542A8DCB4315D96~YAAQB3UsMTnWsgaIAQAAteekMBNXYMd+fXO69SM7VVrBBAWX0kULeJeKzO424YCAofVecuE259HlHq+7EARPcbtklHGEYDfgdCxSqorlyIU4VuhkqO+A+shZFCYJk1MO1bzURdXamWf/NtjXJf9dvHgPA33mYyCkQQP0qZnnM2oDDprg700MUMFvcY/aS4dfMt7+xKGAq8690N4Vjos+D/qca5P79sHxJfMiqCShHZZLjr8O7+EDgNhOh8ylpA==~1',
      'asos-perx': 'faf8d120b9f74c3bbbb75e88c6b2f10f||f75b1ed39966481a85519cad3d49bd1a',
      'AMCVS_C0137F6A52DEAFCC0A490D4C%40AdobeOrg': '1',
      '_s_fpv': 'true',
      's_cc': 'true',
      's_sq': 'asoscomprod%3D%2526c.%2526a.%2526activitymap.%2526page%253Ddesktop%252520row%25257Ccategory%252520page%252520pagination%25257C16691%252520page%2525202%2526link%253DLOAD%252520MORE%2526region%253Dplp%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c',
      'floor': '1001',
      'bm_mi': '7467F1635BD661DEFA5DA08579C9D6C9~~1',
      'plp_columsCount': 'fourColumns',
      'OptanonConsent': 'isGpcEnabled=0&datestamp=Fri+May+19+2023+02%3A24%3A54+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&hosts=&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1',
  }

  headers = {
      'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/113.0',
      'Accept': 'application/json, text/plain, */*',
      'Accept-Language': 'en-US,en;q=0.5',
      # 'Accept-Encoding': 'gzip, deflate, br',
      'asos-cid': '6f4ec78d-ee7f-4813-9786-4e1934851950',
      'asos-c-plat': 'web',
      'asos-c-name': '@asosteam/asos-web-product-listing-page',
      'asos-c-ver': '1.2.0-d7bef89a42ea-8963',
      'Connection': 'keep-alive',
      'Referer': 'https://www.asos.com/men/ctas/usa-fashion-online-14/cat/?cid=16691&page=3',
      # 'Cookie': 'geocountry=IN; _abck=0964C38D588870D3AB8A8A2AD61310FE~0~...~-1~-1~1684446798; bm_sz=830FB7A87E1079BFB86914F1B1D2DB4D~~3356998~3619137; AMCV_C0137F6A52DEAFCC0A490D4C%40AdobeOrg=-1303530583%7CMCMID%7C60069574564088357800626577175423412725%7CvVersion%7C3.3.0%7CMCAID%7CNONE%7CMCOPTOUT-1684450400s%7CNONE; s_pers=%20s_vnum%3D1685557800077%2526vn%253D2%7C1685557800077%3B%20gpv_e231%3Daaea1c58-553f-4186-a485-470a8fbf5138%7C1684445106753%3B%20eVar225%3D6%7C1684445106798%3B%20s_invisit%3Dtrue%7C1684445106804%3B%20visitCount%3D2%7C1684445106810%3B; siteChromeVersion=au=12&com=12&de=12&dk=12&es=12&fr=12&it=12&nl=12&pl=12&roe=12&row=12&ru=12&se=12&us=12; keyStoreDataversion=ornjx7v-36; browseCountry=IN; asos=PreferredSite=&customerguid=faf8d120b9f74c3bbbb75e88c6b2f10f&topcatid=1001; browseCurrency=GBP; browseLanguage=en-GB; browseSizeSchema=UK; storeCode=ROW; currency=1; stc-welcome-message=cappedPageCount=2; featuresId=2f6f608c-9479-4050-abf6-816c593452db; asos-b-sdv629=ornjx7v-36; ak_bmsc=960553D8D25C8448720724CF9E5B0EF5~000000000000000000000000000000~...; bm_sv=8733192C061BDF489542A8DCB4315D96~YAAQB3UsMTnWsgaIAQAAteekMBNXYMd+fXO69SM7VVrBBAWX0kULeJeKzO424YCAofVecuE259HlHq+7EARPcbtklHGEYDfgdCxSqorlyIU4VuhkqO+A+shZFCYJk1MO1bzURdXamWf/NtjXJf9dvHgPA33mYyCkQQP0qZnnM2oDDprg700MUMFvcY/aS4dfMt7+xKGAq8690N4Vjos+D/qca5P79sHxJfMiqCShHZZLjr8O7+EDgNhOh8ylpA==~1; asos-perx=faf8d120b9f74c3bbbb75e88c6b2f10f||f75b1ed39966481a85519cad3d49bd1a; AMCVS_C0137F6A52DEAFCC0A490D4C%40AdobeOrg=1; _s_fpv=true; s_cc=true; s_sq=asoscomprod%3D%2526c.%2526a.%2526activitymap.%2526page%253Ddesktop%252520row%25257Ccategory%252520page%252520pagination%25257C16691%252520page%2525202%2526link%253DLOAD%252520MORE%2526region%253Dplp%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c; floor=1001; bm_mi=7467F1635BD661DEFA5DA08579C9D6C9~~1; plp_columsCount=fourColumns; OptanonConsent=isGpcEnabled=0&datestamp=Fri+May+19+2023+02%3A24%3A54+GMT%2B0530+(India+Standard+Time)&version=202301.2.0&hosts=&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1',
      'Sec-Fetch-Dest': 'empty',
      'Sec-Fetch-Mode': 'cors',
      'Sec-Fetch-Site': 'same-origin',
      'Sec-GPC': '1',
  }

  params = {
      'offset': str(i),
      'store': 'ROW',
      'lang': 'en-GB',
      'currency': 'GBP',
      'rowlength': '4',
      'channel': 'desktop-web',
      'country': 'IN',
      'keyStoreDataversion': 'ornjx7v-36',
      'limit': '72',
  }

  response = requests.get(
      'https://www.asos.com/api/product/search/v2/categories/16691',
      params=params,
      cookies=cookies,
      headers=headers,
  )

  results_json = response.json()
  result_items = results_json['products']
  base_url = 'https://asos.com/'


  for item in result_items:
    name.append(item['name'])
    price.append(item['price']['current']['text'])
    url.append(base_url + item['url'])
    brand.append(item['brandName'])

asos_df = pd.DataFrame({'Name': name, 'Brand': brand, 'Price': price, 'Url': url})
print(asos_df)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.asos.com:443
# 2023-05-18 21:40:41 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.asos.com:443
# DEBUG:urllib3.connectionpool:https://www.asos.com:443 "GET /api/product/search/v2/categories/16691?offset=0&store=ROW&lang=en-GB&currency=GBP&rowlength=4&channel=desktop-web&country=IN&keyStoreDataversion=ornjx7v-36&limit=72 HTTP/1.1" 200 15380
# 2023-05-18 21:40:42 [urllib3.connectionpool] DEBUG: https://www.asos.com:443 "GET /api/product/search/v2/categories/16691?offset=0&store=ROW&lang=en-GB&currency=GBP&rowlength=4&channel=desktop-web&country=IN&keyStoreDataversion=ornjx7v-36&limit=72 HTTP/1.1" 200 15380
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.asos.com:443
# 2023-05-18 21:40:42 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.asos.com:443
# ...

# %%
asos_df
# Out:
#                                                   Name           Brand  \
# 0    ASOS DESIGN oversized t-shirt in white with LA...     ASOS DESIGN
# 1    ASOS DESIGN oversized t-shirt in black with LA...     ASOS DESIGN
# 2    COLLUSION short sleeve t-shirt with graphic in...       Collusion
# 3    The North Face NSE Carabiner back graphic heav...  The North Face
# 4    ASOS DESIGN oversized t-shirt in black with br...     ASOS DESIGN
# ..                                                 ...             ...
# 783  ASOS DESIGN relaxed t-shirt in brown with text...     ASOS DESIGN
# 784    COLLUSION jogger with embroidered logo in khaki       Collusion
# 785        Puma Essentials small logo t-shirt in white            Puma
# 786  Topman relaxed cotton ripstop cargo trousers i...          Topman
# 787  ASOS DESIGN 90s oversized wool mix check shirt...     ASOS DESIGN
#
#       Price                                                Url
# ...

# %%
# Out:
#                                                  Name           Brand   Price  \
# 0   COLLUSION face back print oversized t-shirt in...       Collusion  £15.99
# 1   ASOS DESIGN oversized t-shirt in black with LA...     ASOS DESIGN  £15.00
# 2   COLLUSION short sleeve t-shirt with graphic in...       Collusion  £19.99
# 3   The North Face NSE Carabiner back graphic heav...  The North Face  £48.00
# 4   ASOS DESIGN boxy oversized viscose shirt in brown     ASOS DESIGN  £27.00
# ..                                                ...             ...     ...
# 67            River Island oversized t-shirt in stone    River Island  £13.00
# 68   ASOS DESIGN boxy oversized revere shirt in stone     ASOS DESIGN  £26.00
# 69  Tommy Jeans chest flag logo relaxed fit t-shir...     Tommy Jeans  £21.00
# 70  ASOS DESIGN oversized t-shirt in white with ca...     ASOS DESIGN  £21.00
# 71  ASOS DESIGN relaxed revere shirt in blue textu...     ASOS DESIGN  £27.00
#
# ...
